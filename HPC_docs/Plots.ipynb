# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Error Functions

# %%
def L1(schemes,N):
    error_matrix = []
    for i in (schemes[1:]):
        error = 1.0/N*np.sum(abs(schemes[0] - i))
        error_matrix.append(error)
    return error_matrix

def L2(schemes,N):
    error_matrix = []
    for i in (schemes[1:]):
        error = np.sqrt(1.0/N*(np.sum((schemes[0]-i)**2)))
        error_matrix.append(error)
    return error_matrix

def Linf(schemes):
    error_matrix = []
    for i in (schemes[1:]):
        error = max(abs(schemes[0]-i))
        error_matrix.append(error)
    return error_matrix

def Errors(anal,num):
    # err_1 = L1(anal,num)
    err_2 = L2(anal,num)
    err_inf = Linf(anal,num)
    print('Error based on L1: ', err_1, ', Error based on L2: ', err_2, ', Error base on L_inf: ', err_inf)

# %% [markdown]
# # Grid Size 100

# %%
data_an = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL =0.05\Analytical_Sol_t1.dat")
data_up = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL =0.05\Upwind_t1.dat")
data_wen = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL =0.05\Lax-Wenfroff_t1.dat")
data_FTCS = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL =0.05\FTCS_t1.dat")
data_Fr_005 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL =0.05\Lax-Friedrichs_t10.dat")

err_005_100 = []
err_05_100 = []
err_09_100 = []

x = data_an[:,0]
u = data_an[:,1]
u_up = data_up[:,1]
u_lax = data_wen[:,1]
u_FTCS = data_FTCS[:,1]
u_Fr_005 = data_Fr_005[:,1]
num100_005_1 = np.array([u,u_up,u_lax,u_Fr_005])

data_Up_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL 0.5\Upwind_t1.dat")
data_Wen_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL 0.5\Lax-Wenfroff_t1.dat")
data_Fr_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL 0.5\Lax-Friedrichs_t10.dat")
u_up05 = data_Up_05[:,1]
u_Wen05 = data_Wen_05[:,1]
u_Fr05 = data_Fr_05[:,1]
num100_05_1 = np.array([u,u_up05, u_Wen05, u_Fr05])

data_Up_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL 0.9\Upwind_t1.dat")
data_Wen_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL 0.9\Lax-Wenfroff_t1.dat")
data_Fr_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh100\Time_1\CFL 0.9\Lax-Friedrichs_t10.dat")
u_Fr_09 = data_Fr_09[:,1]
u_Up_09 = data_Up_09[:,1]
u_Wen_09 = data_Wen_09[:,1]
num100_09_1 = ([u,u_Up_09, u_Wen_09, u_Fr_09])

plt.figure(figsize=(9, 8))

plt.subplot(3, 2, 1)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up, label='Upwind')
plt.plot(x, u_FTCS, label='FTCS')
plt.plot(x, u_lax, label='Lax-Wendroff', marker='^', markevery=5, linestyle='',color='orange')
plt.plot(x, u_Fr_005, label='Lax-Friedrichs', marker='<', markevery=5, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=1, CFL=0.05, N=100')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(a)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')


plt.subplot(3, 2, 2)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up05, label='Upwind')
plt.plot(x, u_Wen05, label='Lax-Wendroff', marker='^', markevery=5, linestyle='')
plt.plot(x, u_Fr05, label='Lax-Friedrichs', marker='<', markevery=5, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=1, CFL=0.5, N=100')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(b)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')



plt.subplot(3, 2, 3)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_Up_09, label='Upwind')
plt.plot(x, u_Wen_09, label='Lax-Wendroff', marker='^', markevery=5, linestyle='')
plt.plot(x, u_Fr_09, label='Lax-Friedrichs', marker='<', markevery=5, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=1, CFL=0.9, N=100')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(c)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')


# --------------------------------  TIME 100 ---------------------------------------------------------------------------------------------------
data_an = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL005\Analytical_Sol_t100.dat")
data_up = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL005\Upwind_t100.dat")
data_wen = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL005\Lax-Wenfroff_t100.dat")
data_FTCS = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL005\FTCS_t100.dat")
data_Fr_005 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL005\Lax-Friedrichs_t100.dat")

x = data_an[:, 0]
u = data_an[:, 1]
u_up = data_up[:, 1]
u_lax = data_wen[:, 1]
u_FTCS = data_FTCS[:, 1]
u_Fr_005 = data_Fr_005[:, 1]
num100_005_10 = np.array([u,u_up,u_lax,u_Fr_005])

data_Up_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL05\Upwind_t100.dat")
data_Wen_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL05\Lax-Wenfroff_t100.dat")
data_Fr_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL05\Lax-Friedrichs_t100.dat")
u_up05 = data_Up_05[:, 1]
u_Wen05 = data_Wen_05[:, 1]
u_Fr05 = data_Fr_05[:, 1]
num100_05_10 = np.array([u,u_up05,u_Wen05,u_Fr05])

data_Up_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL09\Upwind_t100.dat")
data_Wen_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL09\Lax-Wenfroff_t100.dat")
data_Fr_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD100\CFL09\Lax-Friedrichs_t100.dat")
u_Fr_09 = data_Fr_09[:, 1]
u_Up_09 = data_Up_09[:, 1]
u_Wen_09 = data_Wen_09[:, 1]
num100_09_10 = np.array([u,u_Up_09,u_Wen_09,u_Fr_09])


plt.subplot(3, 2, 4)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up, label='Upwind')
plt.plot(x, u_lax, label='Lax-Wendroff', marker='^', markevery=5, linestyle='-')
plt.plot(x, u_Fr_005, label='Lax-Friedrichs', marker='<', markevery=5, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=100, CFL=0.05, N=100')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(d)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')

plt.subplot(3, 2, 5)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up05, label='Upwind')
plt.plot(x, u_Wen05, label='Lax-Wendroff', marker='^', markevery=5, linestyle='-')
plt.plot(x, u_Fr05, label='Lax-Friedrichs', marker='<', markevery=5, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=100, CFL=0.5, N=100')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(e)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')

plt.subplot(3, 2, 6)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_Up_09, label='Upwind')
plt.plot(x, u_Wen_09, label='Lax-Wendroff', marker='^', markevery=5, linestyle='-')
plt.plot(x, u_Fr_09, label='Lax-Friedrichs', marker='<', markevery=5, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=100, CFL=0.9, N=100')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(f)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')

plt.tight_layout()
plt.savefig("grid100.pdf", format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Errors

# %%
# Error functions

def ERROR_L1(num0,num_end,N):
    err_init = L1(num0,N)
    err_final = L1(num_end,N)
    res = np.concatenate([err_init,err_final])
    return res
def ERROR_L2(num0,num_end,N):
    err_init = L2(num0,N)
    err_final = L2(num_end,N)
    res = np.concatenate([err_init,err_final])
    return res
def ERROR_inf(num0,num_end):
    err_init = Linf(num0)
    err_final = Linf(num_end)
    res = np.concatenate([err_init,err_final])
    return res

def All_errors(num0,num_end,N):
    a1 = ERROR_L1(num0,num_end,N)
    a2 = ERROR_L2(num0,num_end,N)
    a3 = ERROR_inf(num0,num_end)
    print(a1)
    print(a2)
    print(a3)
    return a1,a2,a3

grid100_1_09,grid100_2_09,grid100_3_09 = All_errors(num100_09_1,num100_09_10,100)
print()
grid100_1_05,grid100_2_05,grid100_3_05 = All_errors(num100_05_1,num100_05_10,100)
print()
grid100_1_005,grid100_2_005,grid100_3_005 = All_errors(num100_005_1,num100_005_10,100)
# Out:
# [0.01244563 0.00255045 0.02790373 0.54450132 0.24841478 0.62190271]
# [0.01388902 0.0028439  0.03074067 0.6077929  0.27560947 0.69414696]
# [0.01974094 0.00484829 0.04306323 0.86383092 0.38852349 0.98653642]
#
# [0.05980648 0.01215587 0.16494324 0.63017123 0.97380864 0.63021031]
# [0.06676828 0.01362563 0.18269023 0.70352948 1.08104164 0.70356253]
# [0.09488853 0.02332877 0.25801961 0.9998274  1.53235651 1.0003556 ]
#
# [0.10878574 0.02211818 0.623499   0.63020068 1.16538835 0.63158327]
# [0.12140138 0.0252545  0.69619773 0.70356236 1.29749405 0.70536731]
# [0.17255171 0.0493677  1.03632499 0.99987412 1.8427972  1.05030273]

# %% [markdown]
# # Grid Size 400

# %%
data_an = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.05\Analytical_Sol_t10.dat")
data_up = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.05\Upwind_t10.dat")
data_wen = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.05\Lax-Wenfroff_t10.dat")
data_FTCS = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.05\FTCS_t10.dat")
data_Fr_005 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.05\Lax-Friedrichs_t10.dat")

x = data_an[:,0]
u = data_an[:,1]
u_up = data_up[:,1]
u_lax = data_wen[:,1]
u_FTCS = data_FTCS[:,1]
u_Fr_005 = data_Fr_005[:,1]
num400_005_1 = np.array([u,u_up,u_lax,u_Fr_005])

data_Up_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.5\Upwind_t10.dat")
data_Wen_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.5\Lax-Wenfroff_t10.dat")
data_Fr_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.5\Lax-Friedrichs_t10.dat")
u_up05 = data_Up_05[:,1]
u_Wen05 = data_Wen_05[:,1]
u_Fr05 = data_Fr_05[:,1]
num400_05_1 = np.array([u,u_up05,u_Wen05,u_Fr05])

data_Up_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.9\Upwind_t10.dat")
data_Wen_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh_400\Time_1\CFL 0.9\Lax-Wenfroff_t10.dat")
data_Fr_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Lax-Friedrichs_t100.dat")
u_Fr_09 = data_Fr_09[:,1]
u_Up_09 = data_Up_09[:,1]
u_Wen_09 = data_Wen_09[:,1]
num400_09_1 = np.array([u,u_Up_09,u_Wen_09,u_Fr_09])

plt.figure(figsize=(9, 8))

plt.subplot(3, 2, 1)
plt.plot(x, u_FTCS, label='FTCS',linestyle='--')
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up, label='Upwind')
plt.plot(x, u_lax, label='Lax-Wendroff', marker='^', markevery=20, linestyle='')
plt.plot(x, u_Fr_005, label='Lax-Friedrichs', marker='<', markevery=20, linestyle='--')

plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=1, CFL=0.05, N=400')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(a)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')

plt.subplot(3, 2, 2)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up05, label='Upwind')
plt.plot(x, u_Wen05, label='Lax-Wendroff', marker='^', markevery=20, linestyle='')
plt.plot(x, u_Fr05, label='Lax-Friedrichs', marker='<', markevery=20, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=1, CFL=0.5, N=400')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(b)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')

plt.subplot(3, 2, 3)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_Up_09, label='Upwind')
plt.plot(x, u_Wen_09, label='Lax-Wendroff', marker='^', markevery=20, linestyle='')
plt.plot(x, u_Fr_09, label='Lax-Friedrichs', marker='<', markevery=20, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=1, CFL=0.9, N=400')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(c)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')

#  ---------------------------------- TIME 10 -------------------------------------------------------------------------------------------------------
data_an = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL005\Analytical_Sol_t100.dat")
data_up = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL005\Upwind_t100.dat")
data_wen = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL005\Lax-Wenfroff_t100.dat")
data_FTCS = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL005\FTCS_t100.dat")
data_Fr_005 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL005\Lax-Friedrichs_t100.dat")

x = data_an[:, 0]
u = data_an[:, 1]
u_up = data_up[:, 1]
u_lax = data_wen[:, 1]
u_FTCS = data_FTCS[:, 1]
u_Fr_005 = data_Fr_005[:, 1]
num400_005_10 = np.array([u,u_up,u_lax,u_Fr_005])

data_Up_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL05\Upwind_t100.dat")
data_Wen_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL05\Lax-Wenfroff_t100.dat")
data_Fr_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL05\Lax-Friedrichs_t100.dat")
u_up05 = data_Up_05[:, 1]
u_Wen05 = data_Wen_05[:, 1]
u_Fr05 = data_Fr_05[:, 1]
num400_05_10 = np.array([u,u_up05,u_Wen05,u_Fr05])


data_Up_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL09\Upwind_t100.dat")
data_Wen_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL09\Lax-Wenfroff_t100.dat")
data_Fr_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD400\CFL09\Lax-Friedrichs_t100.dat")
u_Fr_09 = data_Fr_09[:, 1]
u_Up_09 = data_Up_09[:, 1]
u_Wen_09 = data_Wen_09[:, 1]
num400_09_10 = np.array([u,u_Up_09,u_Wen_09,u_Fr_09])

plt.subplot(3, 2, 4)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up, label='Upwind')
plt.plot(x, u_lax, label='Lax-Wendroff', marker='^', markevery=20, linestyle='-')
plt.plot(x, u_Fr_005, label='Lax-Friedrichs', marker='<', markevery=20, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=100, CFL=0.05, N=400')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(d)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')

plt.subplot(3, 2, 5)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up05, label='Upwind')
plt.plot(x, u_Wen05, label='Lax-Wendroff', marker='^', markevery=20, linestyle='-')
plt.plot(x, u_Fr05, label='Lax-Friedrichs', marker='<', markevery=20, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=100, CFL=0.5, N=400')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(e)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')

plt.subplot(3, 2, 6)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_Up_09, label='Upwind')
plt.plot(x, u_Wen_09, label='Lax-Wendroff', marker='^', markevery=20, linestyle='-')
plt.plot(x, u_Fr_09, label='Lax-Friedrichs', marker='<', markevery=20, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=100, CFL=0.9, N=400')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend(fontsize='x-small')
plt.text(-0.01, 1.05, '(f)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')

plt.tight_layout()
plt.savefig("grid400.pdf", format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Errors

# %%
grid400_1_09,grid400_2_09,grid400_3_09 = All_errors(num400_09_1,num400_09_10,400)
print()
grid400_1_05,grid400_2_05,grid400_3_05 = All_errors(num400_05_1,num400_05_10,400)
print()
grid400_1_005,grid400_2_005,grid400_3_005 = All_errors(num400_005_1,num400_005_10,400)
# Out:
# [0.01551536 0.00263372 0.00671533 0.24783664 0.05327696 0.41289016]
# [0.0172549  0.0029396  0.00744221 0.27561788 0.05916177 0.45906283]
# [0.02443249 0.00529401 0.01051605 0.39027059 0.08506199 0.64999469]
#
# [0.01551536 0.00263372 0.04596326 0.58150504 0.26038732 0.63476783]
# [0.0172549  0.0029396  0.05086369 0.64670192 0.28902537 0.70593364]
# [0.02443249 0.00529401 0.07182039 0.9157129  0.40862326 0.9996118 ]
#
# [0.02915516 0.00495453 0.40752091 0.62925016 0.47804815 0.63504462]
# [0.03242313 0.0055637  0.45083432 0.699799   0.53054312 0.70623331]
# [0.04591064 0.0114939  0.63777    0.99089774 0.7517552  1.0039276 ]

# %% [markdown]
# # Grid Size 1600

# %%
data_an = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.05\Analytical_Sol_t10.dat")
data_up = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.05\Upwind_t10.dat")
data_wen = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.05\Lax-Wenfroff_t10.dat")
data_FTCS = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.05\FTCS_t10.dat")
data_Fr_005 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.05\Lax-Friedrichs_t10.dat")

x = data_an[:,0]
u = data_an[:,1]
u_up = data_up[:,1]
u_lax = data_wen[:,1]
u_FTCS = data_FTCS[:,1]
u_Fr_005 = data_Fr_005[:,1]
num1600_005_1 = np.array([u,u_up,u_lax,u_Fr_005])

data_Up_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.5\Upwind_t10.dat")
data_Wen_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.5\Lax-Wenfroff_t10.dat")
data_Fr_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.5\Lax-Friedrichs_t10.dat")
u_up05 = data_Up_05[:,1]
u_Wen05 = data_Wen_05[:,1]
u_Fr05 = data_Fr_05[:,1]
num1600_05_1 = np.array([u,u_up05,u_Wen05,u_Fr05])

data_Up_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.9\Upwind_t10.dat")
data_Wen_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.9\Lax-Wenfroff_t10.dat")
data_Fr_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\Mesh1600\Time_1\CFL 0.9\Lax-Friedrichs_t10.dat")
u_Fr_09 = data_Fr_09[:,1]
u_Up_09 = data_Up_09[:,1]
u_Wen_09 = data_Wen_09[:,1]
num1600_09_1 = np.array([u,u_Up_09,u_Wen_09,u_Fr_09])


plt.figure(figsize=(9, 8))

plt.subplot(3, 2, 1)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up, label='Upwind')
plt.plot(x, u_lax, label='Lax-Wendroff', marker='^', markevery=80, linestyle='')
plt.plot(x, u_Fr_005, label='Lax-Friedrichs', marker='<', markevery=80, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=1, CFL=0.05, N=1600')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.text(-0.01, 1.05, '(a)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')
plt.legend(fontsize='x-small')

plt.subplot(3, 2, 2)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up05, label='Upwind', marker='*',markevery=80)
plt.plot(x, u_Wen05, label='Lax-Wendroff', marker='^', markevery=80, linestyle='')
plt.plot(x, u_Fr05, label='Lax-Friedrichs', marker='<', markevery=80, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=1, CFL=0.5, N=1600')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.text(-0.01, 1.05, '(b)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')
plt.legend(fontsize='x-small')

plt.subplot(3, 2, 3)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_Up_09, label='Upwind', marker='*',markevery=80)
plt.plot(x, u_Wen_09, label='Lax-Wendroff', marker='^', markevery=80, linestyle='')
plt.plot(x, u_Fr_09, label='Lax-Friedrichs', marker='<', markevery=80, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=1, CFL=0.9, N=1600')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.text(-0.01, 1.05, '(c)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')
plt.legend(fontsize='x-small')

# ------------------------------------------------ TIME 100  -----------------------------------------------------------------------------------------------
data_an = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL005\Analytical_Sol_t100.dat")
data_up = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL005\Upwind_t100.dat")
data_wen = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL005\Lax-Wenfroff_t100.dat")
data_FTCS = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL005\FTCS_t100.dat")
data_Fr_005 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL005\Lax-Friedrichs_t100.dat")


x = data_an[:, 0]
u = data_an[:, 1]
u_up = data_up[:, 1]
u_lax = data_wen[:, 1]
u_FTCS = data_FTCS[:, 1]
u_Fr_005 = data_Fr_005[:, 1]
num1600_005_10 = np.array([u,u_up,u_lax,u_Fr_005])

data_Up_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL05\Upwind_t100.dat")
data_Wen_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL05\Lax-Wenfroff_t100.dat")
data_Fr_05 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL05\Lax-Friedrichs_t100.dat")
u_up05 = data_Up_05[:, 1]
u_Wen05 = data_Wen_05[:, 1]
u_Fr05 = data_Fr_05[:, 1]
num1600_05_10 = np.array([u,u_up05,u_Wen05,u_Fr05])

data_Up_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL09\Upwind_t100.dat")
data_Wen_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL09\Lax-Wenfroff_t100.dat")
data_Fr_09 = np.loadtxt(r"C:\Users\ilias\Desktop\CFD_MSc\Numerical Methods & HPC\Assignment_Docs\Plots\Problem_1\griD1600\CFL09\Lax-Friedrichs_t100.dat")
u_Fr_09 = data_Fr_09[:, 1]
u_Up_09 = data_Up_09[:, 1]
u_Wen_09 = data_Wen_09[:, 1]
num1600_09_10 = np.array([u,u_Up_09,u_Wen_09,u_Fr_09])


plt.subplot(3, 2, 4)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up, label='Upwind', marker='*',markevery=80)
plt.plot(x, u_lax, label='Lax-Wendroff', marker='^', markevery=80, linestyle='-')
plt.plot(x, u_Fr_005, label='Lax-Friedrichs', marker='<', markevery=80, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=100, CFL=0.05, N=1600')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.text(-0.01, 1.05, '(d)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')
plt.legend(fontsize='x-small')

plt.subplot(3, 2, 5)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_up05, label='Upwind', marker='*',markevery=80)
plt.plot(x, u_Wen05, label='Lax-Wendroff', marker='^', markevery=80, linestyle='-')
plt.plot(x, u_Fr05, label='Lax-Friedrichs', marker='<', markevery=80, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=100, CFL=0.5, N=1600')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.text(-0.01, 1.05, '(e)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')
plt.legend(fontsize='x-small')

plt.subplot(3, 2, 6)
plt.plot(x, u, label='Analytical', color='black')
plt.plot(x, u_Up_09, label='Upwind', marker='*',markevery=80)
plt.plot(x, u_Wen_09, label='Lax-Wendroff', marker='^', markevery=80, linestyle='-')
plt.plot(x, u_Fr_09, label='Lax-Friedrichs', marker='<', markevery=80, linestyle='--')
plt.xlim(0, 1)
plt.grid(True, linestyle='--', color='gray', alpha=0.7)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.title('Time=100, CFL=0.9, N=1600')
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.text(-0.01, 1.05, '(f)', transform=plt.gca().transAxes, fontsize=14, fontweight='bold')
plt.legend(fontsize='x-small')

plt.tight_layout()
plt.savefig("grid1600.pdf", format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Errors

# %%
grid1600_1_09,grid1600_2_09,grid1600_3_09 = All_errors(num1600_09_1,num1600_09_10,1600)
print()
grid1600_1_05,grid1600_2_05,grid1600_3_05 = All_errors(num1600_05_1,num1600_05_10,1600)
print()
grid1600_1_005,grid1600_2_005,grid1600_3_005 = All_errors(num1600_005_1,num1600_005_10,1600)
# Out:
# [7.85797520e-04 1.27563947e-04 1.66507273e-03 7.38863934e-02
#  1.27068833e-02 1.46460418e-01]
# [8.73073442e-04 1.42795246e-04 1.84890749e-03 8.20927146e-02
#  1.41131282e-02 1.62708614e-01]
# [0.0012351  0.00063207 0.00261493 0.11613293 0.02037454 0.2301656 ]
#
# [0.0039149  0.00063333 0.01176413 0.29302263 0.06327801 0.53866511]
# [0.00434972 0.00070492 0.01304684 0.32556817 0.07027675 0.59845684]
# [0.00615335 0.00129778 0.0184428  0.46056664 0.0993955  0.84660385]
#
# [0.00741771 0.00120061 0.14194595 0.43930199 0.11962944 0.63622199]
# [0.00824157 0.00133846 0.15656748 0.48809404 0.13284892 0.70688582]
# [0.01165898 0.00259941 0.21979282 0.69048498 0.18793073 1.00024573]

# %% [markdown]
# ## Plot Errors

# %%
time_error = np.array([1.0,100.0])
def plot_L(coarse,medium,fine,time,index,CFL,Lax=True):
    plt.plot(time_error,(coarse[0],coarse[3]),label='grid 100, Upwind')
    plt.plot(time_error,(medium[0],medium[3]),label='grid 400 Upwind')
    plt.plot(time_error,(fine[0],fine[3]),label='grid 1600 Upwind')
    plt.plot(time_error,(coarse[1],coarse[4]),label='grid 100 Lax-Wendroff')
    plt.plot(time_error,(medium[1],medium[4]),label='grid 400 Lax-Wendroff')
    plt.plot(time_error,(fine[1],fine[4]),label='grid 1600 Lax-Wendroff')
    if Lax == True :
        plt.plot(time_error,(coarse[2],coarse[5]),label='grid 100 Lax-Friedrichs')
    plt.plot(time_error,(medium[2],medium[5]),label='grid 400 Lax-Friedrichs')
    plt.plot(time_error,(fine[2],fine[5]),label='grid 1600 Lax-Friedrichs')
    plt.grid(True, linestyle='--', color='gray', alpha=0.7)
    plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
    plt.title(f'CFL={CFL}, L{index}',fontsize = 12, fontweight='bold')
    plt.text(-0.01, 1.05, '(f)', transform=plt.gca().transAxes, fontsize=12, fontweight='bold')
    plt.xlabel('Time',fontsize=10)
    plt.ylabel('Error',fontsize=10)
    plt.legend(fontsize=6)

# %%
plt.figure(figsize=(9, 8))
plt.subplot(3,3,1)
plot_L(grid100_1_005,grid400_1_005,grid1600_1_005,time_error,1,0.05,Lax=False)
plt.subplot(3,3,2)
plot_L(grid100_2_005,grid400_2_005,grid1600_2_005,time_error,2,0.05,Lax=False)
plt.subplot(3,3,3)
plot_L(grid100_3_005,grid400_3_005,grid1600_3_005,time_error,'\u221e',0.05,Lax=False)
plt.subplot(3,3,4)
plot_L(grid100_1_05,grid400_1_05,grid1600_1_05,time_error,1,0.5)
plt.subplot(3,3,5)
plot_L(grid100_2_05,grid400_2_05,grid1600_2_05,time_error,2,0.5)
plt.subplot(3,3,6)
plot_L(grid100_3_05,grid400_3_05,grid1600_3_05,time_error,'\u221e',0.5)
plt.subplot(3,3,7)
plot_L(grid100_1_09,grid400_1_09,grid1600_1_09,time_error,1,0.9)
plt.subplot(3,3,8)
plot_L(grid100_2_09,grid400_2_09,grid1600_2_09,time_error,2,0.9)
plt.subplot(3,3,9)
plot_L(grid100_3_09,grid400_3_09,grid1600_3_09,time_error,'\u221e',0.9)

plt.tight_layout()
plt.show()
